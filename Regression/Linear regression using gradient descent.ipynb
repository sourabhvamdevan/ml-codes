# %%
#Linear regression using gradient descent

import numpy as np
import matplotlib.pyplot as plt


np.random.seed(42)
X = 2 * np.random.rand(100, 1)  
y = 4 + 3 * X + np.random.randn(100, 1)  


plt.scatter(X, y, color="blue", label="Data points")
plt.xlabel("X")
plt.ylabel("y")
plt.title("Synthetic Linear Data")
plt.legend()
plt.show()


def gradient_descent(X, y, learning_rate=0.1, iterations=1000):
    m = len(y)  
    X_b = np.c_[np.ones((m, 1)), X]  
    theta = np.random.randn(2, 1)  
    cost_history = [] 

    for i in range(iterations):
        predictions = X_b.dot(theta)  
        residuals = predictions - y  
        gradients = (2 / m) * X_b.T.dot(residuals)  
        theta -= learning_rate * gradients  
        cost = (1 / m) * np.sum(residuals ** 2)  
        cost_history.append(cost)

        if i % 100 == 0:
            print(f"Iteration {i}: Cost={cost:.4f}")

    return theta, cost_history


theta_final, cost_history = gradient_descent(X, y, learning_rate=0.1, iterations=1000)


print("\nFinal Parameters:")
print(f"Intercept (Bias): {theta_final[0][0]:.4f}")
print(f"Slope: {theta_final[1][0]:.4f}")


plt.plot(range(len(cost_history)), cost_history, color="green")
plt.xlabel("Iteration")
plt.ylabel("Cost (MSE)")
plt.title("Cost Function Convergence")
plt.show()


plt.scatter(X, y, color="blue", label="Data points")
plt.plot(X, X * theta_final[1][0] + theta_final[0][0], color="red", label="Fitted line")
plt.xlabel("X")
plt.ylabel("y")
plt.title("Linear Regression Fit")
plt.legend()
plt.show()
# Out:
# Iteration 0: Cost=31.0093
# Iteration 100: Cost=0.8075
# Iteration 200: Cost=0.8066
# Iteration 300: Cost=0.8066
# Iteration 400: Cost=0.8066
# Iteration 500: Cost=0.8066
# Iteration 600: Cost=0.8066
# Iteration 700: Cost=0.8066
# Iteration 800: Cost=0.8066
# Iteration 900: Cost=0.8066
#
# Final Parameters:
# Intercept (Bias): 4.2151
# Slope: 2.7701
